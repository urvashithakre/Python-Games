# %% [markdown]
# # TIC TAC TOE GAME

# %%
board = [" ", " ", " ",
         " ", " ", " ",
         " ", " ", " "]

game_still_going = True
#winner = None
current_player = "X"

def play_game():
    display_board()
    while game_still_going:
        handle_turn(current_player)
        check_if_game_over()
        flip_player()
    
def display_board():
    print(board[0]+"|"+board[1]+"|"+board[2])
    print("- - -")
    print(board[3]+"|"+board[4]+"|"+board[5])
    print("- - -")
    print(board[6]+"|"+board[7]+"|"+board[8])
    print("")
    print("*****************************")

def handle_turn(player):
    print(player+"'s turn\n")
    position = int(input("Enter a position between 1-9:"))
    position = position-1
    board[position]=player
    display_board()
  
    
def check_if_game_over():
    check_if_winner()
    check_if_tie()
    
def check_if_winner():
    global game_still_going
    
    if board[0]==board[1]==board[2]!=" ":
        print(board[0]+" "+'won')
        game_still_going = False
    elif board[3]==board[4]==board[5]!=" ":
        print(board[3]+" "+'won')
        game_still_going = False
    elif board[3]==board[4]==board[5]!=" ":
        print(board[3]+" "+'won')    
        game_still_going = False
    elif board[6]==board[7]==board[8]!=" ":
        print(board[6]+" "+'won')
        game_still_going = False
    elif board[0]==board[3]==board[6]!=" ":
        print(board[3]+" "+'won') 
        game_still_going = False
    elif board[1]==board[4]==board[7]!=" ":
        print(board[1]+" "+'won')
        game_still_going = False
    elif board[2]==board[5]==board[8]!=" ":
        print(board[2]+" "+'won')
        game_still_going = False
    elif board[0]==board[4]==board[8]!=" ":
        print(board[0]+" "+'won')
        game_still_going = False
    elif board[2]==board[4]==board[6]!=" ":
        print(board[2]+" "+'won')
        game_still_going = False
    else:
        return None
    
def check_if_tie():
    global game_still_going
    if " " not in board:
        game_still_going = False
        print("Its a tie")
        return True
    else:
        return False
        
def flip_player():
    global current_player
    if current_player == "X":
        current_player = "O"
    else:
        current_player = 'X'
            
play_game()
# Out:
#  | |
# - - -
#  | |
# - - -
#  | |
#
# *****************************
# X's turn
#
# Enter a position between 1-9:1
# X| |
# - - -
#  | |
# - - -
#  | |
#
# *****************************
# O's turn
#
# Enter a position between 1-9:3
# X| |O
# - - -
#  | |
# - - -
#  | |
#
# *****************************
# X's turn
#
# Enter a position between 1-9:4
# X| |O
# - - -
# X| |
# - - -
#  | |
#
# *****************************
# O's turn
#
# Enter a position between 1-9:5
# X| |O
# - - -
# X|O|
# - - -
#  | |
#
# *****************************
# X's turn
#
# Enter a position between 1-9:7
# X| |O
# - - -
# X|O|
# - - -
# X| |
#
# *****************************
# X won
